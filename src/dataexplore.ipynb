# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path('/home/deb/PLM-ICD/data/mimic3')
rare100 = True 
trn = data_path/('train_full_rare100.csv' if rare100 else 'train_full.csv')
dev = data_path/'dev_full_rare100.csv' if rare100 else 'dev_full.csv'
tst = data_path/'test_full_rare100.csv' if rare100 else 'test_full.csv'

# %%
df_trn = pd.read_csv(trn, usecols=['SUBJECT_ID', 'HADM_ID', 'TEXT', 'LABELS', 'length'])
df_dev = pd.read_csv(dev, usecols=['SUBJECT_ID', 'HADM_ID', 'TEXT', 'LABELS', 'length'])
df_tst = pd.read_csv(tst, usecols=['SUBJECT_ID', 'HADM_ID', 'TEXT', 'LABELS', 'length'])

# %%
len(df_trn), len(df_dev), len(df_tst)
# Out:
# (22, 59, 11)

# %%
df_trn[df_trn.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, HADM_ID, TEXT, LABELS, length]
# Index: []

# %%
df_dev[df_dev.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, HADM_ID, TEXT, LABELS, length]
# Index: []

# %%
df_tst[df_tst.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SUBJECT_ID, HADM_ID, TEXT, LABELS, length]
# Index: []

# %%
pd.concat((df_trn, df_dev)).sort_values(by='SUBJECT_ID')
# df_trn.sort_values(by='SUBJECT_ID')
# Out:
#     SUBJECT_ID  HADM_ID                                               TEXT  \
# 0        82231   187959  admission date discharge date date of birth se...
# 1        82291   117277  admission date discharge date date of birth se...
# 2        82433   198959  admission date discharge date date of birth se...
# 3        82442   134835  admission date discharge date date of birth se...
# 4        82463   100698  admission date discharge date date of birth se...
# ..         ...      ...                                                ...
# 54       88217   142411  admission date discharge date date of birth se...
# 55       88733   103077  admission date discharge date date of birth se...
# 56       88782   130777  admission date discharge date date of birth se...
# 57       88870   174811  admission date discharge date date of birth se...
# 58       89100   121947  admission date discharge date date of birth se...
#
#            LABELS  length
# 0           58.23     797
# ...

# %%
df_tst.sort_values(by='SUBJECT_ID')
# Out:
#     SUBJECT_ID  HADM_ID                                               TEXT  \
# 0        89124   189821  admission date discharge date date of birth se...
# 1        90604   145942  admission date discharge date date of birth se...
# 2        91975   136078  admission date discharge date date of birth se...
# 3        93601   180558  admission date discharge date date of birth se...
# 4        94525   154715  admission date discharge date date of birth se...
# 5        95294   184592  admission date discharge date date of birth se...
# 6        96025   154310  admission date discharge date service medicine...
# 7        96741   163286  admission date discharge date date of birth se...
# 8        97920   192787  admission date discharge date date of birth se...
# 9        97974   111444  admission date discharge date date of birth se...
# 10       98359   112769  admission date discharge date date of birth se...
#
#     LABELS  length
# 0    284.2    2765
# 1   695.10    3664
# ...
